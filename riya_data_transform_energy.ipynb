# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("data/33100501.csv") #, sep = ",") 
df.head()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_13240\861598527.py:1: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("data/33100501.csv") #, sep = ",")
#    REF_DATE            GEO           DGUID Gender     Type of corporation  \
# 0      2016  Canada, total  2021A000011124  Women  Total all corporations
# 1      2016  Canada, total  2021A000011124  Women  Total all corporations
# 2      2016  Canada, total  2021A000011124  Women  Total all corporations
# 3      2016  Canada, total  2021A000011124  Women  Total all corporations
# 4      2016  Canada, total  2021A000011124  Women  Total all corporations
#
#     Country of control              Industry Size of enterprise  \
# 0  Total all countries  Total all industries    Total all sizes
# 1  Total all countries  Total all industries    Total all sizes
# 2  Total all countries  Total all industries    Total all sizes
# ...

# %%
df = df.drop(['DGUID', 'UOM_ID', 'SCALAR_FACTOR', 'SCALAR_ID', 'VECTOR', 'COORDINATE', 'STATUS', 'SYMBOL', 'TERMINATED', 'DECIMALS' ], axis=1)
df.head()
# Out:
#    REF_DATE            GEO Gender     Type of corporation  \
# 0      2016  Canada, total  Women  Total all corporations
# 1      2016  Canada, total  Women  Total all corporations
# 2      2016  Canada, total  Women  Total all corporations
# 3      2016  Canada, total  Women  Total all corporations
# 4      2016  Canada, total  Women  Total all corporations
#
#     Country of control              Industry Size of enterprise  \
# 0  Total all countries  Total all industries    Total all sizes
# 1  Total all countries  Total all industries    Total all sizes
# 2  Total all countries  Total all industries    Total all sizes
# 3  Total all countries  Total all industries    Total all sizes
# 4  Total all countries  Total all industries    Total all sizes
#
#        Executive Unit of measure      UOM   VALUE
# 0      Directors          Number   Number  5423.0
# 1      Directors      Percentage  Percent    17.8
# 2  All officers           Number   Number  7827.0
# ...

# %%
df = df[df['Unit of measure'] == 'Number']
df.head()
# Out:
#    REF_DATE            GEO Gender     Type of corporation  \
# 0      2016  Canada, total  Women  Total all corporations
# 2      2016  Canada, total  Women  Total all corporations
# 4      2016  Canada, total  Women  Total all corporations
# 6      2016  Canada, total  Women  Total all corporations
# 8      2016  Canada, total  Women  Total all corporations
#
#     Country of control              Industry Size of enterprise  \
# 0  Total all countries  Total all industries    Total all sizes
# 2  Total all countries  Total all industries    Total all sizes
# 4  Total all countries  Total all industries    Total all sizes
# 6  Total all countries  Total all industries    Total all sizes
# 8  Total all countries  Total all industries     First quartile
#
#          Executive Unit of measure     UOM   VALUE
# 0        Directors          Number  Number  5423.0
# 2    All officers           Number  Number  7827.0
# 4    Top officers           Number  Number  2058.0
# ...

# %%
df = df.drop(['Unit of measure', 'UOM'], axis = 1)
df.head()
# Out:
#    REF_DATE            GEO Gender     Type of corporation  \
# 0      2016  Canada, total  Women  Total all corporations
# 2      2016  Canada, total  Women  Total all corporations
# 4      2016  Canada, total  Women  Total all corporations
# 6      2016  Canada, total  Women  Total all corporations
# 8      2016  Canada, total  Women  Total all corporations
#
#     Country of control              Industry Size of enterprise  \
# 0  Total all countries  Total all industries    Total all sizes
# 2  Total all countries  Total all industries    Total all sizes
# 4  Total all countries  Total all industries    Total all sizes
# 6  Total all countries  Total all industries    Total all sizes
# 8  Total all countries  Total all industries     First quartile
#
#          Executive   VALUE
# 0        Directors  5423.0
# 2    All officers   7827.0
# 4    Top officers   2058.0
# 6  Other officers   5769.0
# 8        Directors  1001.0

# %%
# df_energy
df_energy = df[df['Industry'] == 'Energy']
df_energy.head()
# Out:
#      REF_DATE            GEO Gender     Type of corporation  \
# 210      2016  Canada, total  Women  Total all corporations
# 212      2016  Canada, total  Women  Total all corporations
# 214      2016  Canada, total  Women  Total all corporations
# 216      2016  Canada, total  Women  Total all corporations
# 218      2016  Canada, total  Women  Total all corporations
#
#       Country of control Industry Size of enterprise        Executive  VALUE
# 210  Total all countries   Energy    Total all sizes        Directors  171.0
# 212  Total all countries   Energy    Total all sizes    All officers   275.0
# 214  Total all countries   Energy    Total all sizes    Top officers    65.0
# 216  Total all countries   Energy    Total all sizes  Other officers   210.0
# 218  Total all countries   Energy     First quartile        Directors   17.0

# %%
# base, clean, dataset - took the totals off
test = df_energy[df_energy['Country of control'] != 'Total all countries']
test = test[test['Type of corporation'] != 'Total all corporations']
test = test[test['Size of enterprise'] != 'Total all sizes']
test.head()
# Out:
#       REF_DATE            GEO Gender           Type of corporation  \
# 4118      2016  Canada, total  Women  Government business entities
# 4120      2016  Canada, total  Women  Government business entities
# 4122      2016  Canada, total  Women  Government business entities
# 4124      2016  Canada, total  Women  Government business entities
# 4126      2016  Canada, total  Women  Government business entities
#
#      Country of control Industry Size of enterprise        Executive  VALUE
# 4118             Canada   Energy     First quartile        Directors    0.0
# 4120             Canada   Energy     First quartile    All officers     0.0
# 4122             Canada   Energy     First quartile    Top officers     0.0
# 4124             Canada   Energy     First quartile  Other officers     0.0
# 4126             Canada   Energy    Second quartile        Directors    0.0

# %%
male = test[test["Gender"] == "Men"]
male.head()
# Out:
#        REF_DATE            GEO Gender           Type of corporation  \
# 21518      2016  Canada, total    Men  Government business entities
# 21520      2016  Canada, total    Men  Government business entities
# 21522      2016  Canada, total    Men  Government business entities
# 21524      2016  Canada, total    Men  Government business entities
# 21526      2016  Canada, total    Men  Government business entities
#
#       Country of control Industry Size of enterprise        Executive  VALUE
# 21518             Canada   Energy     First quartile        Directors    0.0
# 21520             Canada   Energy     First quartile    All officers     0.0
# 21522             Canada   Energy     First quartile    Top officers     0.0
# 21524             Canada   Energy     First quartile  Other officers     0.0
# 21526             Canada   Energy    Second quartile        Directors    0.0

# %%
test.VALUE.describe()
# Out:
# count    64832.000000
# mean         0.392522
# std          4.612382
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max        327.000000
# Name: VALUE, dtype: float64
